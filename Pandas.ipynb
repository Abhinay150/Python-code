# %%
# 1.Data Creation.
#DataFram()

# %%
import pandas as pd 
import random
data={
    'Name':['Dev','aman','shivam','kamal','arjun','jyoti'],
     'age':[random.randint(20,30) for _ in range(6)],
    'marks':[random.randint(50,99) for _ in range(6)],
    'mobile':[random.randint(100000000,999999999) for _ in range(1,7)]}
frame=pd.DataFrame(data)
frame
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   age     6 non-null      int64
#  2   marks   6 non-null      int64
#  3   mobile  6 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 324.0+ bytes

# %%
#read_csv()
path=r'C:\Users\vikra\Downloads\annual-enterprise-survey-2024-financial-year-provisional-size-bands (1).csv'
data=pd.read_csv(path)
frame=pd.DataFrame(data)
frame
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 21667  2024                  all                     All Industries
# 21668  2024                  all                     All Industries
# 21669  2024                  all                     All Industries
# 21670  2024                  all                     All Industries
# 21671  2024                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
path=r'C:\Users\vikra\Downloads\annual-enterprise-survey-2024-financial-year-provisional-size-bands (1).csv'
data=pd.read_csv(path)
frame=pd.DataFrame(data)
# frame.head()  # start se 5 rows dikhta hai
# frame.tail()     # last ki 5 rows dikhta hai
frame[]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       3 frame=pd.DataFrame(data)
#       4 # frame.head()  # start se 5 rows dikhta hai
#       5 # frame.tail()     # last ki 5 rows dikhta hai
# ----> 6 frame('value')
#
# TypeError: 'DataFrame' object is not callable

# %%
9
